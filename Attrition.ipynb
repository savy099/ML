# %%
import numpy as np
import pandas as pd

# %%
df_att=pd.read_csv(r'C:\Users\saurabh.upman\Desktop\nitish upman - Attrition_Assignment.csv')

# %%
df_att
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
df_att.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
df_att.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %% [markdown]
# # NULL check:

# %%
df_att.isnull().any()
# Out:
# Age                         False
# Attrition                   False
# BusinessTravel              False
# DailyRate                   False
# Department                  False
# DistanceFromHome            False
# Education                   False
# EducationField              False
# EmployeeCount               False
# EmployeeNumber              False
# EnvironmentSatisfaction     False
# Gender                      False
# HourlyRate                  False
# JobInvolvement              False
# JobLevel                    False
# JobRole                     False
# JobSatisfaction             False
# MaritalStatus               False
# MonthlyIncome               False
# MonthlyRate                 False
# NumCompaniesWorked          False
# Over18                      False
# OverTime                    False
# PercentSalaryHike           False
# PerformanceRating           False
# RelationshipSatisfaction    False
# StandardHours               False
# ...

# %%
df_att.shape
# Out:
# (1470, 35)

# %%
df_att['Department'].unique()
# Out:
# array(['Sales', 'Research & Development', 'Human Resources'], dtype=object)

# %% [markdown]
# # Transformating the Attrition column:
#     YES->1
#     NO->0

# %%
df_att['Attrition']=np.where(df_att['Attrition']=='Yes',1,0)

# %%
df_att['Attrition']
# Out:
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0
#        ..
# 1465    0
# 1466    0
# 1467    0
# 1468    0
# 1469    0
# Name: Attrition, Length: 1470, dtype: int32

# %%
df_att['Attrition']=df_att['Attrition'].astype(int)

# %%
df_att.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   int32
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.filterwarnings("ignore", category=RuntimeWarning)

# %% [markdown]
# # Visualization :

# %%
#Bar chart for department employee work for and the frequency of turnover
pd.crosstab(df_att.Department,df_att.Attrition).plot(kind='bar')
plt.title('Turnover Frequency for Department')
plt.xlabel('Department')
plt.ylabel('Frequency of Turnover')
plt.savefig('department_bar_chart')

# %%
pd.crosstab(df_att.EducationField,df_att.Attrition).plot(kind='bar')
plt.title('Turnover Frequency for Department')
plt.xlabel('EducationField')
plt.ylabel('Frequency of Turnover')
plt.savefig('EducationField_bar_chart')

# %%
pd.crosstab(df_att.BusinessTravel,df_att.Attrition).plot(kind='bar')
plt.title('Turnover Frequency for BusinessTravel')
plt.xlabel('BusinessTravel')
plt.ylabel('Frequency of Turnover')
plt.savefig('BusinessTravel_bar_chart')

# %%
pd.crosstab(df_att.Gender,df_att.Attrition).plot(kind='bar')
plt.title('Turnover Frequency for Gender')
plt.xlabel('Gender')
plt.ylabel('Frequency of Turnover')
plt.savefig('Gender_bar_chart')

# %%
pd.crosstab(df_att.OverTime,df_att.Attrition).plot(kind='bar')
plt.title('Turnover Frequency for OverTime')
plt.xlabel('OverTime')
plt.ylabel('Frequency of Turnover')
plt.savefig('OverTime_bar_chart')

# %%
pd.crosstab(df_att.MaritalStatus,df_att.Attrition).plot(kind='bar')
plt.title('Turnover Frequency for MaritalStatus')
plt.xlabel('MaritalStatus')
plt.ylabel('Frequency of Turnover')
plt.savefig('MaritalStatus_bar_chart')

# %%
pd.crosstab(df_att.JobRole,df_att.Attrition).plot(kind='bar')
plt.title('Turnover Frequency for JobRole')
plt.xlabel('JobRole')
plt.ylabel('Frequency of Turnover')
plt.savefig('JobRole_bar_chart')

# %%
#Histogram of numeric variables
num_bins = 10

df_att.hist(bins=num_bins, figsize=(20,15))
plt.savefig("Att_histogram_plots")
plt.show()

# %% [markdown]
# # Feature Engineering:

# %%
#Creating two sets X and Y:
X=df_att.drop(columns=['Attrition'])
y=df_att['Attrition']

# %%
#selecting categorical var's:
Att_categorical = X.select_dtypes(include=['object'])
Att_categorical.head(5)
# Out:
#       BusinessTravel              Department EducationField  Gender  \
# 0      Travel_Rarely                   Sales  Life Sciences  Female
# 1  Travel_Frequently  Research & Development  Life Sciences    Male
# 2      Travel_Rarely  Research & Development          Other    Male
# 3  Travel_Frequently  Research & Development  Life Sciences  Female
# 4      Travel_Rarely  Research & Development        Medical    Male
#
#                  JobRole MaritalStatus Over18 OverTime
# 0        Sales Executive        Single      Y      Yes
# 1     Research Scientist       Married      Y       No
# 2  Laboratory Technician        Single      Y      Yes
# 3     Research Scientist       Married      Y      Yes
# 4  Laboratory Technician       Married      Y       No

# %%
#creating dummy variables
Att_dummies = pd.get_dummies(Att_categorical, drop_first=True)
Att_dummies.head()
# Out:
#    BusinessTravel_Travel_Frequently  BusinessTravel_Travel_Rarely  \
# 0                                 0                             1
# 1                                 1                             0
# 2                                 0                             1
# 3                                 1                             0
# 4                                 0                             1
#
#    Department_Research & Development  Department_Sales  \
# 0                                  0                 1
# 1                                  1                 0
# 2                                  1                 0
# 3                                  1                 0
# 4                                  1                 0
#
#    EducationField_Life Sciences  EducationField_Marketing  \
# 0                             1                         0
# 1                             1                         0
# ...

# %%
#Maximum Age :
df_att['Age'].max()
# Out:
# 60

# %%
#Minimum Age:
df_att['Age'].min()
# Out:
# 18

# %%
#Avg Age:
df_att['Age'].mean()
# Out:
# 36.923809523809524

# %%
#Distinct values in Age column:
df_att['Age'].unique()
# Out:
# array([41, 49, 37, 33, 27, 32, 59, 30, 38, 36, 35, 29, 31, 34, 28, 22, 53,
#        24, 21, 42, 44, 46, 39, 43, 50, 26, 48, 55, 45, 56, 23, 51, 40, 54,
#        58, 20, 25, 19, 57, 52, 47, 18, 60], dtype=int64)

# %% [markdown]
# # Binning Age column:

# %%
df_att['Age_Bins'] = pd.cut(df_att['Age'],[18,25,32,42,52,60],include_lowest=True)

# %%
print(df_att[['Age','Age_Bins']])
# Out:
#       Age      Age_Bins
# 0      41  (32.0, 42.0]
# 1      49  (42.0, 52.0]
# 2      37  (32.0, 42.0]
# 3      33  (32.0, 42.0]
# 4      27  (25.0, 32.0]
# ...   ...           ...
# 1465   36  (32.0, 42.0]
# 1466   39  (32.0, 42.0]
# 1467   27  (25.0, 32.0]
# 1468   49  (42.0, 52.0]
# 1469   34  (32.0, 42.0]
#
# [1470 rows x 2 columns]

# %%
dummy_Age=pd.get_dummies(df_att['Age_Bins'],columns=['Age_Bins'],prefix='Age')
print(dummy_Age.columns)
# Out:
# Index(['Age_(17.999, 25.0]', 'Age_(25.0, 32.0]', 'Age_(32.0, 42.0]',
#        'Age_(42.0, 52.0]', 'Age_(52.0, 60.0]'],
#       dtype='object')

# %%
dummy_Age
# Out:
#       Age_(17.999, 25.0]  Age_(25.0, 32.0]  Age_(32.0, 42.0]  \
# 0                      0                 0                 1
# 1                      0                 0                 0
# 2                      0                 0                 1
# 3                      0                 0                 1
# 4                      0                 1                 0
# ...                  ...               ...               ...
# 1465                   0                 0                 1
# 1466                   0                 0                 1
# 1467                   0                 1                 0
# 1468                   0                 0                 0
# 1469                   0                 0                 1
#
#       Age_(42.0, 52.0]  Age_(52.0, 60.0]
# 0                    0                 0
# 1                    1                 0
# 2                    0                 0
# 3                    0                 0
# ...

# %%
def dummy1(input_df):
    dummy_Age[input_df]=np.where((dummy_Age[input_df]==1) ,(df_att['Age']),0)

# %%
for i in dummy_Age.columns:
    dummy1(i)

# %%
dummy_Age
# Out:
#       Age_(17.999, 25.0]  Age_(25.0, 32.0]  Age_(32.0, 42.0]  \
# 0                      0                 0                41
# 1                      0                 0                 0
# 2                      0                 0                37
# 3                      0                 0                33
# 4                      0                27                 0
# ...                  ...               ...               ...
# 1465                   0                 0                36
# 1466                   0                 0                39
# 1467                   0                27                 0
# 1468                   0                 0                 0
# 1469                   0                 0                34
#
#       Age_(42.0, 52.0]  Age_(52.0, 60.0]
# 0                    0                 0
# 1                   49                 0
# 2                    0                 0
# 3                    0                 0
# ...

# %%
#Exclude the categorical vars from df:
X=X.drop(columns=Att_categorical)
X.head(5)
# Out:
#    Age  DailyRate  DistanceFromHome  Education  EmployeeCount  EmployeeNumber  \
# 0   41       1102                 1          2              1               1
# 1   49        279                 8          1              1               2
# 2   37       1373                 2          2              1               4
# 3   33       1392                 3          4              1               5
# 4   27        591                 2          1              1               7
#
#    EnvironmentSatisfaction  HourlyRate  JobInvolvement  JobLevel  ...  \
# 0                        2          94               3         2  ...
# 1                        3          61               2         2  ...
# 2                        4          92               2         1  ...
# 3                        4          56               3         1  ...
# 4                        1          40               3         1  ...
#
#    RelationshipSatisfaction  StandardHours  StockOptionLevel  \
# ...

# %%
dfX1=pd.merge(X,Att_dummies,on=X.index)
dfX1
# Out:
#       key_0  Age  DailyRate  DistanceFromHome  Education  EmployeeCount  \
# 0         0   41       1102                 1          2              1
# 1         1   49        279                 8          1              1
# 2         2   37       1373                 2          2              1
# 3         3   33       1392                 3          4              1
# 4         4   27        591                 2          1              1
# ...     ...  ...        ...               ...        ...            ...
# 1465   1465   36        884                23          2              1
# 1466   1466   39        613                 6          1              1
# 1467   1467   27        155                 4          3              1
# 1468   1468   49       1023                 2          3              1
# 1469   1469   34        628                 8          3              1
#
#       EmployeeNumber  EnvironmentSatisfaction  HourlyRate  JobInvolvement  \
# ...

# %%
dfX1.drop(columns='key_0',inplace=True)
dfX1
# Out:
#       Age  DailyRate  DistanceFromHome  Education  EmployeeCount  \
# 0      41       1102                 1          2              1
# 1      49        279                 8          1              1
# 2      37       1373                 2          2              1
# 3      33       1392                 3          4              1
# 4      27        591                 2          1              1
# ...   ...        ...               ...        ...            ...
# 1465   36        884                23          2              1
# 1466   39        613                 6          1              1
# 1467   27        155                 4          3              1
# 1468   49       1023                 2          3              1
# 1469   34        628                 8          3              1
#
#       EmployeeNumber  EnvironmentSatisfaction  HourlyRate  JobInvolvement  \
# 0                  1                        2          94               3
# ...

# %%
#dfX1.drop(columns='Age',inplace=True)
#dfX1
# Out:
#       DailyRate  DistanceFromHome  Education  EmployeeCount  EmployeeNumber  \
# 0          1102                 1          2              1               1
# 1           279                 8          1              1               2
# 2          1373                 2          2              1               4
# 3          1392                 3          4              1               5
# 4           591                 2          1              1               7
# ...         ...               ...        ...            ...             ...
# 1465        884                23          2              1            2061
# 1466        613                 6          1              1            2062
# 1467        155                 4          3              1            2064
# 1468       1023                 2          3              1            2065
# 1469        628                 8          3              1            2068
#
# ...

# %%
dfX=pd.merge(dfX1,dummy_Age,on=dfX1.index)
dfX
# Out:
#       key_0  Age  DailyRate  DistanceFromHome  Education  EmployeeCount  \
# 0         0   41       1102                 1          2              1
# 1         1   49        279                 8          1              1
# 2         2   37       1373                 2          2              1
# 3         3   33       1392                 3          4              1
# 4         4   27        591                 2          1              1
# ...     ...  ...        ...               ...        ...            ...
# 1465   1465   36        884                23          2              1
# 1466   1466   39        613                 6          1              1
# 1467   1467   27        155                 4          3              1
# 1468   1468   49       1023                 2          3              1
# 1469   1469   34        628                 8          3              1
#
#       EmployeeNumber  EnvironmentSatisfaction  HourlyRate  JobInvolvement  \
# ...

# %%
dfX.drop(columns='key_0',inplace=True)
dfX
# Out:
#       Age  DailyRate  DistanceFromHome  Education  EmployeeCount  \
# 0      41       1102                 1          2              1
# 1      49        279                 8          1              1
# 2      37       1373                 2          2              1
# 3      33       1392                 3          4              1
# 4      27        591                 2          1              1
# ...   ...        ...               ...        ...            ...
# 1465   36        884                23          2              1
# 1466   39        613                 6          1              1
# 1467   27        155                 4          3              1
# 1468   49       1023                 2          3              1
# 1469   34        628                 8          3              1
#
#       EmployeeNumber  EnvironmentSatisfaction  HourlyRate  JobInvolvement  \
# 0                  1                        2          94               3
# ...

# %%
dfX.drop(columns='Age',inplace=True)
dfX
# Out:
#       DailyRate  DistanceFromHome  Education  EmployeeCount  EmployeeNumber  \
# 0          1102                 1          2              1               1
# 1           279                 8          1              1               2
# 2          1373                 2          2              1               4
# 3          1392                 3          4              1               5
# 4           591                 2          1              1               7
# ...         ...               ...        ...            ...             ...
# 1465        884                23          2              1            2061
# 1466        613                 6          1              1            2062
# 1467        155                 4          3              1            2064
# 1468       1023                 2          3              1            2065
# 1469        628                 8          3              1            2068
#
# ...

# %% [markdown]
# # Feature Scaling:

# %%
from sklearn.preprocessing import scale

# %%
cols=dfX.columns
dfX_scaled=pd.DataFrame(scale(dfX))
dfX_scaled.columns=cols
dfX_scaled.columns
# Out:
# Index(['DailyRate', 'DistanceFromHome', 'Education', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobSatisfaction', 'MonthlyIncome',
#        'MonthlyRate', 'NumCompaniesWorked', 'PercentSalaryHike',
#        'PerformanceRating', 'RelationshipSatisfaction', 'StandardHours',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole',
#        'YearsSinceLastPromotion', 'YearsWithCurrManager',
#        'BusinessTravel_Travel_Frequently', 'BusinessTravel_Travel_Rarely',
#        'Department_Research & Development', 'Department_Sales',
#        'EducationField_Life Sciences', 'EducationField_Marketing',
#        'EducationField_Medical', 'EducationField_Other',
#        'EducationField_Technical Degree', 'Gender_Male',
#        'JobRole_Human Resources', 'JobRole_Laboratory Technician',
# ...

# %%
dfX_scaled.describe()
# Out:
#           DailyRate  DistanceFromHome     Education  EmployeeCount  \
# count  1.470000e+03      1.470000e+03  1.470000e+03         1470.0
# mean   7.197568e-17      5.164048e-17  2.697011e-16            0.0
# std    1.000340e+00      1.000340e+00  1.000340e+00            0.0
# min   -1.736576e+00     -1.010909e+00 -1.868426e+00            0.0
# 25%   -8.366616e-01     -8.875151e-01 -8.916883e-01            0.0
# 50%   -1.204135e-03     -2.705440e-01  8.504925e-02            0.0
# 75%    8.788772e-01      5.932157e-01  1.061787e+00            0.0
# max    1.726730e+00      2.444129e+00  2.038524e+00            0.0
#
#        EmployeeNumber  EnvironmentSatisfaction    HourlyRate  JobInvolvement  \
# count    1.470000e+03             1.470000e+03  1.470000e+03    1.470000e+03
# mean     1.132881e-16             7.054070e-17  1.728021e-16   -6.495182e-18
# std      1.000340e+00             1.000340e+00  1.000340e+00    1.000340e+00
# ...

# %% [markdown]
# # Split into test and train data:

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(dfX_scaled, y, train_size=0.7,test_size = 0.3, random_state=0)

# %%
X_train
# Out:
#       DailyRate  DistanceFromHome  Education  EmployeeCount  EmployeeNumber  \
# 338   -0.576356         -0.517332   0.085049            0.0       -0.945242
# 363   -1.121758         -0.517332   0.085049            0.0       -0.897055
# 759   -0.035912          1.827158   1.061787            0.0        0.040103
# 793    0.229352          0.716610  -0.891688            0.0        0.128169
# 581    0.293809         -1.010909   0.085049            0.0       -0.363673
# ...         ...               ...        ...            ...             ...
# 763    1.315199          0.099639   1.061787            0.0        0.050073
# 835   -0.680478         -0.147150   1.061787            0.0        0.231190
# 1216   0.933417         -0.887515   0.085049            0.0        1.131792
# 559   -1.325045         -0.887515   2.038524            0.0       -0.418506
# 684   -0.358195          0.099639   1.061787            0.0       -0.117752
#
# ...

# %%
y_train
# Out:
# 338     0
# 363     1
# 759     0
# 793     0
# 581     0
#        ..
# 763     0
# 835     0
# 1216    0
# 559     0
# 684     0
# Name: Attrition, Length: 1029, dtype: int32

# %% [markdown]
# # Feature Selection & Model building:

# %%
#Logistic Reg model taking all the features:
#Logistic Regression Classifier
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
lr = LogisticRegression()
lr.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
from sklearn.metrics import accuracy_score
#from sklearn.learning_curve import validation_curve
from sklearn.model_selection import learning_curve, GridSearchCV
from colorama import Fore, Back, Style 
from sklearn.metrics import confusion_matrix
from sklearn.metrics import recall_score
   
# Predict using model
y_pred_test = lr.predict(X_test)
y_pred_train = lr.predict(X_train)
    
#Accuracy for C in range [0.001,100]  :    
print ("Accuracy for test data : \n",accuracy_score(y_test,y_pred_test)*100)
print ("Accuracy for train data : \n",accuracy_score(y_train,y_pred_train)*100)
    
cm_test=confusion_matrix(y_test,y_pred_test)
cm_train=confusion_matrix(y_train,y_pred_train)
print("Recall for test data \n",recall_score(y_test, y_pred_test))
print("Recall for train data \n",recall_score(y_train, y_pred_train))
print("Confusion Matrix for test:",cm_test)
print("Confusion Matrix for train:",cm_train)
# Out:
# Accuracy for test data :
#  88.66213151927438
# Accuracy for train data :
#  89.50437317784257
# Recall for test data
#  0.42857142857142855
# Recall for train data
#  0.47904191616766467
# Confusion Matrix for test: [[361  10]
#  [ 40  30]]
# Confusion Matrix for train: [[841  21]
#  [ 87  80]]

# %%
print('Logistic regression accuracy: {:.3f}'.format(accuracy_score(y_test, lr.predict(X_test))*100))
# Out:
# Logistic regression accuracy: 88.889

# %%
plt.style.use('ggplot')
fig, ax=plt.subplots(figsize=(20,10))
sns.lineplot(x=y_test.index,y=y_test,label='Actuals',color='blue',ax=ax)
sns.lineplot(x=y_test.index,y=y_pred_test,label='Predictions',color='red',ax=ax)
ax.set_title('Attrition: Actuals vs Predictions')
ax.set_ylabel('Attrition')
ax.set_xlabel('Index')
# Out:
# Text(0.5, 0, 'Index')

# %% [markdown]
# # Performance tunning of hyperparameters:

# %%
#lr = LogisticRegression(penalty = 'l2', C = 100,max_iter=50,random_state = 0)
lr = LogisticRegression(penalty = 'l2', C = 100,max_iter=50,random_state = 0)
lr.fit(X_train, y_train)
# Out:
# C:\Users\saurabh.upman\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(C=100, max_iter=50, random_state=0)

# %%
# Predict using model
y_pred_test = lr.predict(X_test)
y_pred_train = lr.predict(X_train)
    
#Accuracy for C in range [0.001,100]  :    
print ("Accuracy for test data : \n",accuracy_score(y_test,y_pred_test)*100)
print ("Accuracy for train data : \n",accuracy_score(y_train,y_pred_train)*100)
    
cm_test=confusion_matrix(y_test,y_pred_test)
cm_train=confusion_matrix(y_train,y_pred_train)
print("Recall for test data \n",recall_score(y_test, y_pred_test))
print("Recall for train data \n",recall_score(y_train, y_pred_train))
print("Confusion Matrix for test:",cm_test)
print("Confusion Matrix for train:",cm_train)
# Out:
# Accuracy for test data :
#  88.88888888888889
# Accuracy for train data :
#  89.31000971817298
# Recall for test data
#  0.44285714285714284
# Recall for train data
#  0.48502994011976047
# Confusion Matrix for test: [[361  10]
#  [ 39  31]]
# Confusion Matrix for train: [[838  24]
#  [ 86  81]]

# %% [markdown]
# # Random forest model:

# %%
#Random Forest Classifier
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier()
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
# Predict using model
y_pred_test = rf.predict(X_test)
y_pred_train = rf.predict(X_train)
    
#Accuracy for C in range [0.001,100]  :    
print ("Accuracy for test data : \n",accuracy_score(y_test,y_pred_test)*100)
print ("Accuracy for train data : \n",accuracy_score(y_train,y_pred_train)*100)
    
cm_test=confusion_matrix(y_test,y_pred_test)
cm_train=confusion_matrix(y_train,y_pred_train)
print("Recall for test data \n",recall_score(y_test, y_pred_test))
print("Recall for train data \n",recall_score(y_train, y_pred_train))
print("Confusion Matrix for test:",cm_test)
print("Confusion Matrix for train:",cm_train)
# Out:
# Accuracy for test data :
#  86.39455782312925
# Accuracy for train data :
#  100.0
# Recall for test data
#  0.15714285714285714
# Recall for train data
#  1.0
# Confusion Matrix for test: [[370   1]
#  [ 59  11]]
# Confusion Matrix for train: [[862   0]
#  [  0 167]]

# %%
print('Random Forest Accuracy: {:.3f}'.format(accuracy_score(y_test, rf.predict(X_test))*100))
# Out:
# Random Forest Accuracy: 86.395

# %% [markdown]
# # SVM model:

# %%
#SVM Classifier
from sklearn.svm import SVC
svc = SVC()
svc.fit(X_train, y_train)
# Out:
# SVC()

# %%
# Predict using model
y_pred_test = svc.predict(X_test)
y_pred_train = svc.predict(X_train)
    
#Accuracy for C in range [0.001,100]  :    
print ("Accuracy for test data : \n",accuracy_score(y_test,y_pred_test)*100)
print ("Accuracy for train data : \n",accuracy_score(y_train,y_pred_train)*100)
    
cm_test=confusion_matrix(y_test,y_pred_test)
cm_train=confusion_matrix(y_train,y_pred_train)
print("Recall for test data \n",recall_score(y_test, y_pred_test))
print("Recall for train data \n",recall_score(y_train, y_pred_train))
print("Confusion Matrix for test:",cm_test)
print("Confusion Matrix for train:",cm_train)
# Out:
# Accuracy for test data :
#  86.62131519274377
# Accuracy for train data :
#  92.03109815354713
# Recall for test data
#  0.17142857142857143
# Recall for train data
#  0.5089820359281437
# Confusion Matrix for test: [[370   1]
#  [ 58  12]]
# Confusion Matrix for train: [[862   0]
#  [ 82  85]]

# %%
print('Random Forest Accuracy: {:.3f}'.format(accuracy_score(y_test, svc.predict(X_test))*100))
# Out:
# Random Forest Accuracy: 86.621

# %%
#RFE [Feature selection]:Logistic regression classifier and summarize the rfe
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression
from sklearn.datasets import make_friedman1
from sklearn.feature_selection import RFE
#from sklearn.svm import SVR
rfe = RFE(lr, n_features_to_select= None)
rfe = rfe.fit(X_train, y_train)
print(rfe.support_)
print(rfe.ranking_)
X_train.columns[rfe.support_]
# Out:
# C:\Users\saurabh.upman\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\saurabh.upman\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %%
df_display=pd.DataFrame()
df_display['Rank']=rfe.ranking_
df_display['Features']=X_train.columns
df_display.sort_values(by=['Rank'])
# Out:
#     Rank                           Features
# 50     1                   Age_(52.0, 60.0]
# 22     1                 YearsInCurrentRole
# 21     1                     YearsAtCompany
# 20     1                    WorkLifeBalance
# 49     1                   Age_(42.0, 52.0]
# 18     1                  TotalWorkingYears
# 27     1  Department_Research & Development
# 28     1                   Department_Sales
# 29     1       EducationField_Life Sciences
# 31     1             EducationField_Medical
# 35     1            JobRole_Human Resources
# 23     1            YearsSinceLastPromotion
# 12     1                 NumCompaniesWorked
# 39     1          JobRole_Research Director
# 9      1                    JobSatisfaction
# 41     1            JobRole_Sales Executive
# 42     1       JobRole_Sales Representative
# 44     1               MaritalStatus_Single
# 5      1            EnvironmentSatisfaction
# 45     1                       OverTime_Yes
# ...

# %%
cols=['Age_(52.0, 60.0]',
'YearsInCurrentRole',
'YearsAtCompany',
'WorkLifeBalance',
'Age_(42.0, 52.0]',
'TotalWorkingYears',
'Department_Research & Development',
'Department_Sales',
'EducationField_Life Sciences',
'EducationField_Medical',
'JobRole_Human Resources',
'YearsSinceLastPromotion',
'NumCompaniesWorked',
'JobRole_Research Director',
'JobSatisfaction',
'JobRole_Sales Executive',
'JobRole_Sales Representative',
'MaritalStatus_Single',
'EnvironmentSatisfaction',
'OverTime_Yes',
'Age_(17.999, 25.0]',
'Age_(25.0, 32.0]',
'Age_(32.0, 42.0]',
'JobRole_Laboratory Technician',
'YearsWithCurrManager'] 
X_ref=dfX[cols]
y_ref=df_att['Attrition']

# %%
#Split test and train data:
from sklearn.model_selection import train_test_split
X_train_ref, X_test_ref, y_train_ref, y_test_ref = train_test_split(X_ref,y_ref, train_size=0.7,test_size = 0.3, random_state=0)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
lr_ref = LogisticRegression(penalty = 'l2', C = 100,max_iter=50,random_state = 0)
lr_ref.fit(X_train_ref, y_train_ref)
# Out:
# C:\Users\saurabh.upman\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(C=100, max_iter=50, random_state=0)

# %%
# Predict using model
y_pred_test_ref = lr_ref.predict(X_test_ref)
y_pred_train_ref = lr_ref.predict(X_train_ref)
    
#Accuracy for C in range [0.001,100]  :    
print ("Accuracy for test data : \n",accuracy_score(y_test_ref,y_pred_test_ref)*100)
print ("Accuracy for train data : \n",accuracy_score(y_train_ref,y_pred_train_ref)*100)
    
cm_test_ref=confusion_matrix(y_test_ref,y_pred_test_ref)
cm_train_ref=confusion_matrix(y_train_ref,y_pred_train_ref)
print("Recall for test data \n",recall_score(y_test_ref, y_pred_test_ref))
print("Recall for train data \n",recall_score(y_train_ref, y_pred_train_ref))
print("Confusion Matrix for test:",cm_test_ref)
print("Confusion Matrix for train:",cm_train_ref)
# Out:
# Accuracy for test data :
#  87.3015873015873
# Accuracy for train data :
#  88.0466472303207
# Recall for test data
#  0.37142857142857144
# Recall for train data
#  0.38323353293413176
# Confusion Matrix for test: [[359  12]
#  [ 44  26]]
# Confusion Matrix for train: [[842  20]
#  [103  64]]

# %%
#Random Forest Classifier
from sklearn.ensemble import RandomForestClassifier
rf_ref = RandomForestClassifier()
rf_ref.fit(X_train_ref, y_train_ref)
# Out:
# RandomForestClassifier()

# %%
# Predict using model
y_pred_test_ref = rf_ref.predict(X_test_ref)
y_pred_train_ref = rf_ref.predict(X_train_ref)
    
#Accuracy for C in range [0.001,100]  :    
print ("Accuracy for test data : \n",accuracy_score(y_test_ref,y_pred_test_ref)*100)
print ("Accuracy for train data : \n",accuracy_score(y_train_ref,y_pred_train_ref)*100)
    
cm_test_ref=confusion_matrix(y_test_ref,y_pred_test_ref)
cm_train_ref=confusion_matrix(y_train_ref,y_pred_train_ref)
print("Recall for test data \n",recall_score(y_test_ref, y_pred_test_ref))
print("Recall for train data \n",recall_score(y_train_ref, y_pred_train_ref))
print("Confusion Matrix for test:",cm_test_ref)
print("Confusion Matrix for train:",cm_train_ref)
# Out:
# Accuracy for test data :
#  85.26077097505669
# Accuracy for train data :
#  100.0
# Recall for test data
#  0.21428571428571427
# Recall for train data
#  1.0
# Confusion Matrix for test: [[361  10]
#  [ 55  15]]
# Confusion Matrix for train: [[862   0]
#  [  0 167]]

# %%
#SVM Classifier
from sklearn.svm import SVC
svc_ref = SVC()
svc_ref.fit(X_train_ref, y_train_ref)
# Out:
# SVC()

# %%
# Predict using model
y_pred_test_ref = svc_ref.predict(X_test_ref)
y_pred_train_ref = svc_ref.predict(X_train_ref)
    
#Accuracy for C in range [0.001,100]  :    
print ("Accuracy for test data : \n",accuracy_score(y_test_ref,y_pred_test_ref)*100)
print ("Accuracy for train data : \n",accuracy_score(y_train_ref,y_pred_train_ref)*100)
    
cm_test_ref=confusion_matrix(y_test_ref,y_pred_test_ref)
cm_train_ref=confusion_matrix(y_train_ref,y_pred_train_ref)
print("Recall for test data \n",recall_score(y_test_ref, y_pred_test_ref))
print("Recall for train data \n",recall_score(y_train_ref, y_pred_train_ref))
print("Confusion Matrix for test:",cm_test_ref)
print("Confusion Matrix for train:",cm_train_ref)
# Out:
# Accuracy for test data :
#  84.12698412698413
# Accuracy for train data :
#  83.77065111758989
# Recall for test data
#  0.0
# Recall for train data
#  0.0
# Confusion Matrix for test: [[371   0]
#  [ 70   0]]
# Confusion Matrix for train: [[862   0]
#  [167   0]]

# %% [markdown]
# # K-Fold cross validation:

# %%
#For Random Forest
from sklearn import model_selection
from sklearn.model_selection import cross_val_score
kfold = model_selection.KFold(n_splits=10, random_state=7)
modelCV = RandomForestClassifier()
scoring = 'accuracy'
results = model_selection.cross_val_score(modelCV, X_train_ref, y_train_ref, cv=kfold, scoring=scoring)
print("10-fold cross validation average accuracy for Random Forest Classifier: %.3f" % (results.mean()))
# Out:
# 10-fold cross validation average accuracy for Random Forest Classifier: 0.857

# %%
#For SVM
from sklearn import model_selection
from sklearn.model_selection import cross_val_score
kfold = model_selection.KFold(n_splits=10, random_state=7)
modelCV = SVC()
scoring = 'accuracy'
results = model_selection.cross_val_score(modelCV, X_train_ref, y_train_ref, cv=kfold, scoring=scoring)
print("10-fold cross validation average accuracy for SVM Classifier: %.3f" % (results.mean()))
# Out:
# 10-fold cross validation average accuracy for SVM Classifier: 0.838

# %%
#LogisticRegression
from sklearn import model_selection
from sklearn.model_selection import cross_val_score
kfold = model_selection.KFold(n_splits=10, random_state=7)
modelCV = LogisticRegression(penalty = 'l2', C =100,max_iter=50,random_state =100)
scoring = 'accuracy'
results = model_selection.cross_val_score(modelCV, X_train_ref, y_train_ref, cv=kfold, scoring=scoring)
print("10-fold cross validation average accuracy for LogisticRegression Classifier: %.3f" % (results.mean()))
# Out:
# C:\Users\saurabh.upman\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\saurabh.upman\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %%
#PRScores for Logistic Regression
from sklearn.metrics import classification_report
print(classification_report(y_test_ref, lr_ref.predict(X_test_ref)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.97      0.93       371
#            1       0.68      0.37      0.48        70
#
#     accuracy                           0.87       441
#    macro avg       0.79      0.67      0.70       441
# weighted avg       0.86      0.87      0.86       441

# %%
#Confusion Matrix for Logistic Regression
logreg_y_pred = lr_ref.predict(X_test_ref)
logreg_cm = metrics.confusion_matrix(logreg_y_pred, y_test_ref, [1,0])
sns.heatmap(logreg_cm, annot=True, fmt='.2f',xticklabels = ["Left", "Stayed"] , yticklabels = ["Left", "Stayed"] )
plt.ylabel('True class')
plt.xlabel('Predicted class')
plt.title('Logistic Regression')
plt.savefig('logistic_regression')

# %% [markdown]
# # ROC Curve

# %%
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve

#ROC for logistic regression
logit_roc_auc = roc_auc_score(y_test_ref, lr_ref.predict(X_test_ref))
fpr, tpr, thresholds = roc_curve(y_test_ref, lr_ref.predict_proba(X_test_ref)[:,1])

#ROC for Random Forrest
rf_roc_auc = roc_auc_score(y_test_ref, rf_ref.predict(X_test_ref))
rf_fpr, rf_tpr, rf_thresholds = roc_curve(y_test_ref, rf_ref.predict_proba(X_test_ref)[:,1])

#ROC Curve for Random Forest & Logistic Regression
plt.figure()
plt.plot(fpr, tpr, label='Logistic Regression (area = %0.2f)' % logit_roc_auc)
plt.plot(rf_fpr, rf_tpr, label='Random Forest (area = %0.2f)' % rf_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.savefig('ROC')
plt.show()

# %% [markdown]
# # LOGISTIC REG IS THE BEST MODEL FOR THIS DATASET
